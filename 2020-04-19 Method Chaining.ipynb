# %%
import pandas as pd

pd.options.mode.chained_assignment = None
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df = pd.read_csv('real_estate_data.csv',sep='\t')

# %%
df.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %% [markdown]
# balcony, is_apartment, open_plan, studio

# %%
df['balcony'] = df['balcony'].fillna(0).astype(int)
df['is_apartment'] = df['is_apartment'].fillna(0).astype(int)
df['open_plan'] = df['open_plan'].fillna(0).astype(int)
df['studio'] = df['studio'].fillna(0).astype(int)

# %%
df.assign(
    balcony = lambda x: x['balcony'].fillna(0).astype(int),
    is_apartment = lambda x: x['is_apartment'].fillna(0).astype(int),
    open_plan = lambda x: x['open_plan'].fillna(0).astype(int),
    studio = lambda x: x['studio'].fillna(0).astype(int),
    living_to_total = lambda x: x['living_area'] / x['total_area']
)
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 0                20 13000000.000     108.000  2019-03-07T00:00:00      3
# 1                 7  3350000.000      40.400  2018-12-04T00:00:00      1
# 2                10  5196000.000      56.000  2015-08-20T00:00:00      2
# 3                 0 64900000.000     159.000  2015-07-24T00:00:00      3
# 4                 2 10000000.000     100.000  2018-06-19T00:00:00      2
# ...             ...          ...         ...                  ...    ...
# 23694             9  9700000.000     133.810  2017-03-21T00:00:00      3
# 23695            14  3100000.000      59.000  2018-01-15T00:00:00      3
# 23696            18  2500000.000      56.700  2018-02-11T00:00:00      2
# 23697            13 11475000.000      76.750  2017-03-28T00:00:00      2
# 23698             4  1350000.000      32.300  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
pd.read_csv('real_estate_data.csv',sep='\t').\
assign(
    balcony = lambda x: x['balcony'].fillna(0).astype(int),
    is_apartment = lambda x: x['is_apartment'].fillna(0).astype(int),
    open_plan = lambda x: x['open_plan'].fillna(0).astype(int),
    studio = lambda x: x['studio'].fillna(0).astype(int),
    living_to_total = lambda x: x['living_area'] / x['total_area']
)
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 0                20 13000000.000     108.000  2019-03-07T00:00:00      3
# 1                 7  3350000.000      40.400  2018-12-04T00:00:00      1
# 2                10  5196000.000      56.000  2015-08-20T00:00:00      2
# 3                 0 64900000.000     159.000  2015-07-24T00:00:00      3
# 4                 2 10000000.000     100.000  2018-06-19T00:00:00      2
# ...             ...          ...         ...                  ...    ...
# 23694             9  9700000.000     133.810  2017-03-21T00:00:00      3
# 23695            14  3100000.000      59.000  2018-01-15T00:00:00      3
# 23696            18  2500000.000      56.700  2018-02-11T00:00:00      2
# 23697            13 11475000.000      76.750  2017-03-28T00:00:00      2
# 23698             4  1350000.000      32.300  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
for col in ['balcony', 'is_apartment', 'open_plan', 'studio']:
    df[col] = df[col].fillna(0).astype(int)

# %%
def fillna_and_convert_to_int(df,columns):
    df = df.copy()
    for col in columns:
        df[col] = df[col].fillna(0).astype(int)
    return df

# %%
pd.read_csv('real_estate_data.csv',sep='\t').\
pipe(abcd).\
pipe(fillna_and_convert_to_int,['balcony', 'is_apartment', 'open_plan', 'studio'])
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 0                20 13000000.000     108.000  2019-03-07T00:00:00      3
# 1                 7  3350000.000      40.400  2018-12-04T00:00:00      1
# 2                10  5196000.000      56.000  2015-08-20T00:00:00      2
# 3                 0 64900000.000     159.000  2015-07-24T00:00:00      3
# 4                 2 10000000.000     100.000  2018-06-19T00:00:00      2
# ...             ...          ...         ...                  ...    ...
# 23694             9  9700000.000     133.810  2017-03-21T00:00:00      3
# 23695            14  3100000.000      59.000  2018-01-15T00:00:00      3
# 23696            18  2500000.000      56.700  2018-02-11T00:00:00      2
# 23697            13 11475000.000      76.750  2017-03-28T00:00:00      2
# 23698             4  1350000.000      32.300  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
other_function(fillna_and_convert_to_int(df,['balcony', 'is_apartment', 'open_plan', 'studio']),other_param)
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 0                20 13000000.000     108.000  2019-03-07T00:00:00      3
# 1                 7  3350000.000      40.400  2018-12-04T00:00:00      1
# 2                10  5196000.000      56.000  2015-08-20T00:00:00      2
# 3                 0 64900000.000     159.000  2015-07-24T00:00:00      3
# 4                 2 10000000.000     100.000  2018-06-19T00:00:00      2
# ...             ...          ...         ...                  ...    ...
# 23694             9  9700000.000     133.810  2017-03-21T00:00:00      3
# 23695            14  3100000.000      59.000  2018-01-15T00:00:00      3
# 23696            18  2500000.000      56.700  2018-02-11T00:00:00      2
# 23697            13 11475000.000      76.750  2017-03-28T00:00:00      2
# 23698             4  1350000.000      32.300  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# func(func1(func2(df)))

# %%
df.func1().\
func2().\
func3()

# %%
def create_floor_group(df):
    if df['floor'] == 1:
        return 1
    elif df['floor'] == df['floors_total']:
        return 3
    else:
        return 2

# %%
pd.read_csv('real_estate_data.csv',sep='\t').\
pipe(fillna_and_convert_to_int,['balcony', 'is_apartment', 'open_plan', 'studio']).\
assign(first_day_exposition = lambda x: pd.to_datetime(x['first_day_exposition'],format='%Y-%m-%dT%H:%M:%S'),
      floor_group = lambda x: x.apply(create_floor_group, axis=1))
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 0                20 13000000.000     108.000           2019-03-07      3
# 1                 7  3350000.000      40.400           2018-12-04      1
# 2                10  5196000.000      56.000           2015-08-20      2
# 3                 0 64900000.000     159.000           2015-07-24      3
# 4                 2 10000000.000     100.000           2018-06-19      2
# ...             ...          ...         ...                  ...    ...
# 23694             9  9700000.000     133.810           2017-03-21      3
# 23695            14  3100000.000      59.000           2018-01-15      3
# 23696            18  2500000.000      56.700           2018-02-11      2
# 23697            13 11475000.000      76.750           2017-03-28      2
# 23698             4  1350000.000      32.300           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
def make_new_params(df):
    """Добавляем новые параметры"""
    df = df.copy()
    df['price_per_area'] = df['last_price'] / df['total_area']
    df['kithcen_to_total']= df['kitchen_area'] / df['total_area']
    df['living_to_total'] = df['living_area'] / df['total_area']
    df['years_of_expositon'] = 
    return df

# %%
pd.read_csv('real_estate_data.csv',sep='\t').\
pipe(fillna_and_convert_to_int,['balcony', 'is_apartment', 'open_plan', 'studio']).\
pipe(make_new_params).\ # Добавляем новые параметры
assign(first_day_exposition = lambda x: pd.to_datetime(x['first_day_exposition'],format='%Y-%m-%dT%H:%M:%S'),
      floor_group = lambda x: x.apply(create_floor_group, axis=1))
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 0                20 13000000.000     108.000           2019-03-07      3
# 1                 7  3350000.000      40.400           2018-12-04      1
# 2                10  5196000.000      56.000           2015-08-20      2
# 3                 0 64900000.000     159.000           2015-07-24      3
# 4                 2 10000000.000     100.000           2018-06-19      2
# ...             ...          ...         ...                  ...    ...
# 23694             9  9700000.000     133.810           2017-03-21      3
# 23695            14  3100000.000      59.000           2018-01-15      3
# 23696            18  2500000.000      56.700           2018-02-11      2
# 23697            13 11475000.000      76.750           2017-03-28      2
# 23698             4  1350000.000      32.300           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
def preproccessing(df):
    df = df.copy()
    df = df.\
        pipe(fillna_and_convert_to_int,['balcony', 'is_apartment', 'open_plan', 'studio']).\
        pipe(make_new_params).\
        assign(first_day_exposition = lambda x: pd.to_datetime(x['first_day_exposition'],format='%Y-%m-%dT%H:%M:%S'),
          floor_group = lambda x: x.apply(create_floor_group, axis=1))
    return df

# %%
proc_df = pd.read_csv('real_estate_data.csv',sep='\t').pipe(preproccessing)

# %%
proc_df_2 = proc_df[proc_df['last_price'] > proc_df['last_price'].median()]

# %%
grouped_df = proc_df_2.groupby(['floor_group','rooms']).agg({'total_area':'mean',
                                                             'last_price':'mean',
                                                            'total_images':'size'})
grouped_df
# Out:
#                    total_area    last_price  total_images
# floor_group rooms
# 1           0          58.900   6225000.000             2
#             1          51.205   6828820.207            82
#             2          62.006   6806773.803           340
#             3          75.079   7698526.479           426
#             4          97.542   9353081.879           124
#             5         128.490  13421465.600            40
#             6         174.533  16369577.778             9
#             7         257.100  29316815.200             5
#             8         229.567  25063333.333             3
#             9         399.000  68984450.000             2
# 2           0          81.711  14263222.222             9
#             1          44.738   6176953.318          1416
#             2          62.214   7679547.718          3346
#             3          83.125   9857159.090          3427
#             4         116.611  15886458.928           712
# ...

# %%
rename(columns={('total','sum'):('total_2','summa')})

# %%
grouped_df_2 = grouped_df.\
rename(columns={'total_images':'total_objects'}).\
reset_index().\
sort_values(['total_objects'],ascending=False)
grouped_df_2
# Out:
#     floor_group  rooms  total_area    last_price  total_objects
# 13            2      3      83.125   9857159.090           3427
# 12            2      2      62.214   7679547.718           3346
# 11            2      1      44.738   6176953.318           1416
# 14            2      4     116.611  15886458.928            712
# 28            3      3      84.338   9850703.592            593
# 27            3      2      63.959   8248136.593            450
# 3             1      3      75.079   7698526.479            426
# 2             1      2      62.006   6806773.803            340
# 15            2      5     162.364  23475438.010            207
# 29            3      4     125.419  16420280.048            167
# 26            3      1      45.145   6324513.696            135
# 4             1      4      97.542   9353081.879            124
# 1             1      1      51.205   6828820.207             82
# 16            2      6     193.259  28921924.629             70
# ...

# %%
grouped_df_2[grouped_df_2['total_objects'] > 100].\
assign(price_to_area_ratio = lambda x: x['last_price'] / x['total_area'])
# Out:
#     floor_group  rooms  total_area   last_price  total_objects  \
# 13            2      3      83.125  9857159.090           3427
# 12            2      2      62.214  7679547.718           3346
# 11            2      1      44.738  6176953.318           1416
# 14            2      4     116.611 15886458.928            712
# 28            3      3      84.338  9850703.592            593
# 27            3      2      63.959  8248136.593            450
# 3             1      3      75.079  7698526.479            426
# 2             1      2      62.006  6806773.803            340
# 15            2      5     162.364 23475438.010            207
# 29            3      4     125.419 16420280.048            167
# 26            3      1      45.145  6324513.696            135
# 4             1      4      97.542  9353081.879            124
#
#     price_to_area_ratio
# 13           118581.872
# 12           123437.278
# 11           138070.324
# 14           136234.359
# ...

# %%
proc_df.\
loc[proc_df['last_price'] > proc_df['last_price'].median()].\
groupby(['floor_group','rooms']).agg({'total_area':'mean',
                                       'last_price':'mean',
                                    'total_images':'size'}).\
rename(columns={'total_images':'total_objects'}).\
reset_index().\
sort_values(['total_objects'],ascending=False).\
loc[lambda x: x['total_objects'] > 100].\
assign(price_to_area_ratio = lambda x: x['last_price'] / x['total_area'])
# Out:
#     floor_group  rooms  total_area   last_price  total_objects  \
# 13            2      3      83.125  9857159.090           3427
# 12            2      2      62.214  7679547.718           3346
# 11            2      1      44.738  6176953.318           1416
# 14            2      4     116.611 15886458.928            712
# 28            3      3      84.338  9850703.592            593
# 27            3      2      63.959  8248136.593            450
# 3             1      3      75.079  7698526.479            426
# 2             1      2      62.006  6806773.803            340
# 15            2      5     162.364 23475438.010            207
# 29            3      4     125.419 16420280.048            167
# 26            3      1      45.145  6324513.696            135
# 4             1      4      97.542  9353081.879            124
#
#     price_to_area_ratio
# 13           118581.872
# 12           123437.278
# 11           138070.324
# 14           136234.359
# ...

# %%
proc_df.\
loc[proc_df['last_price'] > proc_df['last_price'].median()].\
groupby(['floor_group','rooms']).agg({'total_area':'mean',
                                       'last_price':'mean',
                                    'total_images':'size'}).\
rename(columns={'total_images':'total_objects'}).\
reset_index().\
sort_values(['total_objects'],ascending=False).\
loc[lambda x: x['total_objects'] > 100].\
assign(price_to_area_ratio = lambda x: x['last_price'] / x['total_area'])

# %%
proc_df.\
loc[proc_df['last_price'] > proc_df['last_price'].median()].\
groupby(['floor_group','rooms']).agg({'total_area':'mean',
                                       'last_price':'mean',
                                    'total_images':'size'}).\
rename(columns={'total_images':'total_objects'}).\
reset_index().\
sort_values(['total_objects'],ascending=False).\
query('total_objects > 100').\
eval('price_to_area_ratio = last_price / total_area')
# Out:
#     floor_group  rooms  total_area   last_price  total_objects  \
# 13            2      3      83.125  9857159.090           3427
# 12            2      2      62.214  7679547.718           3346
# 11            2      1      44.738  6176953.318           1416
# 14            2      4     116.611 15886458.928            712
# 28            3      3      84.338  9850703.592            593
# 27            3      2      63.959  8248136.593            450
# 3             1      3      75.079  7698526.479            426
# 2             1      2      62.006  6806773.803            340
# 15            2      5     162.364 23475438.010            207
# 29            3      4     125.419 16420280.048            167
# 26            3      1      45.145  6324513.696            135
# 4             1      4      97.542  9353081.879            124
#
#     price_to_area_ratio
# 13           118581.872
# 12           123437.278
# 11           138070.324
# 14           136234.359
# ...

# %%
def show_df(df):
    df = df.copy()
    display(df)
    return df

# %%
proc_df.\
loc[proc_df['last_price'] > proc_df['last_price'].median()].\
pipe(show_df).\
groupby(['floor_group','rooms']).agg({'total_area':'mean',
                                       'last_price':'mean',
                                    'total_images':'size'}).\
rename(columns={'total_images':'total_objects'}).\
reset_index().\
sort_values(['total_objects'],ascending=False).\
pipe(show_df).\
query('total_objects > 100').\
eval('price_to_area_ratio = last_price / total_area')
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 0                20 13000000.000     108.000           2019-03-07      3
# 2                10  5196000.000      56.000           2015-08-20      2
# 3                 0 64900000.000     159.000           2015-07-24      3
# 4                 2 10000000.000     100.000           2018-06-19      2
# 7                 5  7915000.000      71.600           2019-04-18      2
# ...             ...          ...         ...                  ...    ...
# 23688            19  9200000.000     101.000           2019-04-01      3
# 23690             3  5500000.000      52.000           2018-07-19      2
# 23691            11  9470000.000      72.900           2016-10-13      2
# 23694             9  9700000.000     133.810           2017-03-21      3
# 23697            13 11475000.000      76.750           2017-03-28      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
df[['a','e']].\
merge(df2[['a','b','c']],how='left',on='a').\
merge(df3[['b','d']],how=)

# %%
proc[proc_df['last_price'] > proc_df['last_price'].median()]
proc.loc[proc_df['last_price'] > proc_df['last_price'].median()]
